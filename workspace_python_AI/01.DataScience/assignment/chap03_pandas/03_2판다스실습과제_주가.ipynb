# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# 1. TikTok 주가 데이터 다운로드
ticker = "TTOO"  # TikTok (티커 코드 예시)
tiktok_data = yf.download(ticker, start="2020-01-01", end="2023-12-31")

# 데이터 확인
print("TikTok 주가 데이터 샘플:\n", tiktok_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# TikTok 주가 데이터 샘플:
#  Price      Adj Close   Close    High     Low    Open Volume
# Ticker          TTOO    TTOO    TTOO    TTOO    TTOO   TTOO
# Date
# 2020-01-02    5800.0  5800.0  6500.0  5650.0  5950.0     72
# 2020-01-03    6150.0  6150.0  6350.0  5650.0  5700.0     70
# 2020-01-06    5950.0  5950.0  6200.0  5500.0  6150.0     84
# 2020-01-07    5950.0  5950.0  6150.0  5800.0  6150.0     45
# 2020-01-08    5750.0  5750.0  6000.0  5650.0  6000.0     44

# %%
tiktok_data.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %% [markdown]
# # 연습 문제 제안
# 문제 1: 특정 날짜의 데이터 가져오기
# python
# 코드 복사
# ### 질문: 2023년 5월 15일의 데이터를 가져오세요.

# %%
# 2. 연습 문제 예제 생성
# 문제 1: 특정 날짜의 주가 정보 가져오기
specific_date_data = tiktok_data.loc['2023-05-15']
print("\n2022-01-03의 데이터:\n", specific_date_data)
# Out:
# 2022-01-03의 데이터:
#  Price      Ticker
# Adj Close  TTOO         27.500000
# Close      TTOO         27.500000
# High       TTOO         28.799999
# Low        TTOO         26.400000
# Open       TTOO         28.799999
# Volume     TTOO      13172.000000
# Name: 2023-05-15 00:00:00, dtype: float64

# %% [markdown]
# 문제 2: 특정 기간의 데이터 가져오기
# python
# 코드 복사
# ### 질문: 2022년 전체 데이터만 추출하세요.

# %%
# 문제 2: 특정 기간(1년)의 데이터 가져오기
one_year_data = tiktok_data.loc['2022']
print("\n2021년 TikTok 데이터:\n", one_year_data.head())
# Out:
# 2021년 TikTok 데이터:
#  Price      Adj Close   Close    High     Low    Open Volume
# Ticker          TTOO    TTOO    TTOO    TTOO    TTOO   TTOO
# Date
# 2022-01-03    2830.0  2830.0  2875.0  2565.0  2565.0    334
# 2022-01-04    2650.0  2650.0  2830.0  2565.0  2805.0    327
# 2022-01-05    2500.0  2500.0  2725.0  2465.0  2650.0    253
# 2022-01-06    2400.0  2400.0  2640.0  2325.0  2450.0    291
# 2022-01-07    2340.0  2340.0  2450.0  2330.0  2330.0    186

# %% [markdown]
# 문제 3: 조건에 맞는 데이터 필터링
# python
# 코드 복사
# ### 질문: 종가가 2달러 이하인 날의 데이터를 추출하세요.

# %%
tiktok_data
# Out:
# Price      Adj Close     Close      High      Low     Open   Volume
# Ticker          TTOO      TTOO      TTOO     TTOO     TTOO     TTOO
# Date
# 2020-01-02  5800.000  5800.000  6500.000  5650.00  5950.00       72
# 2020-01-03  6150.000  6150.000  6350.000  5650.00  5700.00       70
# 2020-01-06  5950.000  5950.000  6200.000  5500.00  6150.00       84
# 2020-01-07  5950.000  5950.000  6150.000  5800.00  6150.00       45
# 2020-01-08  5750.000  5750.000  6000.000  5650.00  6000.00       44
# ...              ...       ...       ...      ...      ...      ...
# 2023-12-22     5.220     5.220     5.250     4.86     4.86   196100
# 2023-12-26     4.870     4.870     5.190     4.76     5.19   193200
# 2023-12-27     5.160     5.160     5.227     4.83     4.83   167700
# 2023-12-28     7.450     7.450     8.380     5.10     5.10  3595200
# 2023-12-29     6.275     6.275     7.721     6.10     7.18   841400
#
# [1006 rows x 6 columns]

# %%
tiktok_data.columns
# Out:
# MultiIndex([('Adj Close', 'TTOO'),
#             (    'Close', 'TTOO'),
#             (     'High', 'TTOO'),
#             (      'Low', 'TTOO'),
#             (     'Open', 'TTOO'),
#             (   'Volume', 'TTOO')],
#            names=['Price', 'Ticker'])

# %%
# 문제 3: 종가(Close)가 5달러 이상인 날의 데이터 필터링
high_price_data = tiktok_data.loc[tiktok_data[('Close', 'TTOO')]>=5]
print("\n종가가 5달러 이상인 데이터:\n", high_price_data.head())
# Out:
# 종가가 5달러 이상인 데이터:
#  Price      Adj Close   Close    High     Low    Open Volume
# Ticker          TTOO    TTOO    TTOO    TTOO    TTOO   TTOO
# Date
# 2020-01-02    5800.0  5800.0  6500.0  5650.0  5950.0     72
# 2020-01-03    6150.0  6150.0  6350.0  5650.0  5700.0     70
# 2020-01-06    5950.0  5950.0  6200.0  5500.0  6150.0     84
# 2020-01-07    5950.0  5950.0  6150.0  5800.0  6150.0     45
# 2020-01-08    5750.0  5750.0  6000.0  5650.0  6000.0     44

# %% [markdown]
# 문제 4: 거래량이 많은 날 분석
# python
# 코드 복사
# ### 질문: 거래량이 2백만 이상인 데이터를 추출하고, 해당 데이터의 평균 종가를 계산하세요.

# %%
# 문제 4: 거래량(Volume)이 1,000,000 이상인 날의 데이터 필터링
high_volume_data = tiktok_data.loc[tiktok_data[('Volume', 'TTOO')] >= 1000000]
print("\n거래량이 1,000,000 이상인 데이터:\n", high_volume_data.head())
print("\n평균 종가 : \n", high_volume_data.Close.mean())
# Out:
# 거래량이 1,000,000 이상인 데이터:
#  Price      Adj Close Close  High   Low  Open   Volume
# Ticker          TTOO  TTOO  TTOO  TTOO  TTOO     TTOO
# Date
# 2023-05-30      13.5  13.5  22.6  11.5  12.5  2337608
# 2023-06-01      10.6  10.6  13.2   8.9  12.5  1140790
# 2023-06-05       7.0   7.0  14.7   6.9  13.9  1436940
# 2023-06-06       7.9   7.9   9.2   7.0   8.2  1520514
# 2023-06-14       7.5   7.5   7.6   6.5   6.8  1211675
#
# 평균 종가 :
#  Ticker
# TTOO    23.642024
# dtype: float64

# %% [markdown]
# 문제 5: 시각화
# python
# 코드 복사
# ### 질문: 2021년 데이터를 사용하여 종가(Close)와 거래량(Volume)의 트렌드를 시각화하세요.

# %%
# 문제 5: 특정 기간의 종가 데이터를 시각화
one_year_data = tiktok_data.loc['2021']
plt.figure(figsize=(12, 6))
plt.plot(one_year_data.index, one_year_data["Close"], label="TikTok Close Price (2021)", color="purple")
plt.title("TikTok Close Prices in 2021")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(one_year_data.index, one_year_data["Close"], label="Close Price", color="blue")
plt.bar(one_year_data.index, one_year_data["Volume","TTOO"], label="Volume", color="orange", alpha=0.5)
plt.title("TikTok Stock Close Price and Volume in 2021")
plt.xlabel("Date")
plt.ylabel("Value")
plt.legend()
plt.show()
