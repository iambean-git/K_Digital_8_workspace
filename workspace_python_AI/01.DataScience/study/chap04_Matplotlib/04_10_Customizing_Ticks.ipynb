# %% [markdown]
# ## 눈금 맞춤 변경하기

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

# %matplotlib inline

# %%
ax = plt.axes(xscale='log', yscale='log')
ax.set(xlim=(1, 1E3), ylim=(1, 1E3))
ax.grid(True);

# %%
print(ax.xaxis.get_major_locator())
print(ax.xaxis.get_minor_locator())
# Out:
# <matplotlib.ticker.LogLocator object at 0x0000028BBF5119D0>
# <matplotlib.ticker.LogLocator object at 0x0000028BCF700770>

# %%
print(ax.xaxis.get_major_formatter())
print(ax.xaxis.get_minor_formatter())
# Out:
# <matplotlib.ticker.LogFormatterSciNotation object at 0x0000028BCE63C980>
# <matplotlib.ticker.LogFormatterSciNotation object at 0x0000028BCE6F74D0>

# %% [markdown]
# ### 눈금 또는 레이블 숨기기

# %%
ax = plt.axes()
rng = np.random.default_rng(1701)
ax.plot(rng.random(50))
ax.grid()

#아래 두줄 주석해서 차이 비교해보기 (눈금, 주석 없애기)
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(5, 5, figsize=(5, 5))
fig.subplots_adjust(hspace=0, wspace=0)

# Get some face data from Scikit-Learn
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces().images

for i in range(5):
    for j in range(5):
        #아래 두개 주석 달고 실행해보기 (눈금과 레이블이 표시되어 지저분해짐)
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        ax[i, j].imshow(faces[10 * i + j], cmap='binary_r')
